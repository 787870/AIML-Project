# %%
import numpy as np 
import string
from nltk.corpus import stopwords
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
# For tab-separated values
df = pd.read_csv(r'C:\aslam\Jarvis.txt', sep='\t')

# For pipe-separated values
df = pd.read_csv(r'C:\aslam\Jarvis.txt', sep='|')

# %%
with open(r'C:\aslam\Jarvis.txt', 'r') as f:
    for _ in range(10):
        print(f.readline())
# Out:
# hi, how are you doing?	i'm fine. how about yourself?
#
# i'm fine. how about yourself?	i'm pretty good. thanks for asking.
#
# i'm pretty good. thanks for asking.	no problem. so how have you been?
#
# no problem. so how have you been?	i've been great. what about you?
#
# i've been great. what about you?	i've been good. i'm in school right now.
#
# i've been good. i'm in school right now.	what school do you go to?
#
# what school do you go to?	i go to pcc.
#
# i go to pcc.	do you like it there?
#
# do you like it there?	it's okay. it's a really big campus.
#
# it's okay. it's a really big campus.	good luck with school.

# %%
a = pd.Series(df.columns)

# %%
df
# Out:
#                                                   input  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                response
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %%
a = a.rename({0: df.columns[0],1: df.columns[1]})

# %%
b = {'Questions':'Hi','Answers':'hello'}

# %%
c = {'Questions':'Hello','Answers':'hi'}

# %%
d= {'Questions':'how are you','Answers':"i'm fine. how about yourself?"}

# %%
e= {'Questions':'how are you doing','Answers':"i'm fine. how about yourself?"}

# %%
df = pd.concat([df, a], ignore_index=True)

# %%
df.columns=['Questions','Answers']

# %%
b = pd.DataFrame([b]) if isinstance(b, dict) else b
c = pd.DataFrame([c]) if isinstance(c, dict) else c
d = pd.DataFrame([d]) if isinstance(d, dict) else d
e = pd.DataFrame([e]) if isinstance(e, dict) else e

df = pd.concat([df, b, c, d, e], ignore_index=True)

# %%
df
# Out:
#                                 Questions  \
# 0                  hi, how are you doing?
# 1           i'm fine. how about yourself?
# 2     i'm pretty good. thanks for asking.
# 3       no problem. so how have you been?
# 4        i've been great. what about you?
# ...                                   ...
# 3725                                  NaN
# 3726                                   Hi
# 3727                                Hello
# 3728                          how are you
# 3729                    how are you doing
#
#                                        Answers  \
# 0                i'm fine. how about yourself?
# 1          i'm pretty good. thanks for asking.
# 2            no problem. so how have you been?
# 3             i've been great. what about you?
# 4     i've been good. i'm in school right now.
# ...                                        ...
# 3725                                       NaN
# 3726                                     hello
# ...

# %%
df = pd.concat([df, c], ignore_index=True)

# %%
df = pd.concat([df, d], ignore_index=True)

# %%
df = pd.concat([df, d], ignore_index=True)

# %%
df
# Out:
#                                 Questions  \
# 0                  hi, how are you doing?
# 1           i'm fine. how about yourself?
# 2     i'm pretty good. thanks for asking.
# 3       no problem. so how have you been?
# 4        i've been great. what about you?
# ...                                   ...
# 3728                          how are you
# 3729                    how are you doing
# 3730                                Hello
# 3731                          how are you
# 3732                          how are you
#
#                                        Answers    0
# 0                i'm fine. how about yourself?  NaN
# 1          i'm pretty good. thanks for asking.  NaN
# 2            no problem. so how have you been?  NaN
# 3             i've been great. what about you?  NaN
# 4     i've been good. i'm in school right now.  NaN
# ...                                        ...  ...
# 3728             i'm fine. how about yourself?  NaN
# ...

# %%
def cleaner(x):
    return [a for a in (''.join([a for a in x if a not in string.punctuation])).lower().split()]

# %%
Pipe = Pipeline([
    ('bow',CountVectorizer(analyzer=cleaner)),
    ('tfidf',TfidfTransformer()),
    ('classifier',DecisionTreeClassifier())
])

# %%
df = df.dropna(subset=['Questions', 'Answers'])  # remove rows with missing questions or answers

# %%
Pipe.fit(df['Questions'], df['Answers'])
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function cleaner at 0x00000171B107D360>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', DecisionTreeClassifier())])

# %%
Pipe.predict(['hi'])[0]
# Out:
# 'hello'

# %%
Pipe.predict(['how are you'])[0]
# Out:
# "i'm fine. how about yourself?"

# %%
Pipe.predict(['great'])[0]
# Out:
# 'i appreciate that.'

# %%
Pipe.predict(['What are you doing'])[0]
# Out:
# "i'm going to change the light bulb. it burnt out."

# %%
Pipe.predict(['where are you now'])[0]
# Out:
# 'i have to walk the dog.'
